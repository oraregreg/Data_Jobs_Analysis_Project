# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  
import ast

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

#convert skill list column into a list
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)  
    return skill_list  # Return the original NaN value

df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
#filter to get only the data analyst jobs

df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
df_DA
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
#we are going to be aggregating the skills on a monthly basis
#create a new column of job_posted_month

df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %%
#create a new dataframe and explode the contents of df_DA

df_DA_exploded = df_DA.explode('job_skills')
df_DA_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_DA_pivot = df_DA_exploded.pivot_table(
    index='job_posted_month_no', 
    columns='job_skills', 
    aggfunc='size',
    fill_value=0 )#fills the NaN values with zero

# %%
#we need to create a row called total that sums up the values in the newly created pivot columns
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot.loc['Total'].sort_values(ascending=False).index

df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
# Out:
# job_skills              sql   excel  python  tableau  power bi       r  \
# job_posted_month_no
# 1                     11336    8170    6606     5596      4285    3607
# 2                      7947    5772    4751     3936      3307    2576
# 3                      7868    5675    4741     4051      3176    2650
# 4                      7553    5496    4557     3776      3106    2399
# 5                      6617    4773    4070     3245      2695    2093
# 6                      7584    5724    4707     3812      3275    2442
# 7                      7687    5513    4831     3928      3350    2444
# 8                      8823    6482    5576     4533      3859    2975
# 9                      6829    4886    4229     3446      3118    2146
# 10                     7474    5217    4693     3709      3340    2380
# 11                     6652    4776    4233     3284      3012    2159
# 12                     6058    4376    4196     3139      2857    2125
# ...

# %%
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
# Plot top 5 skills
df_DA_pivot.iloc[:, :5].plot(kind='line', marker='o', figsize=(14, 8))
plt.title('Top 5 Data Analyst Skills - Monthly Trends (2023)', fontsize=16)
plt.ylabel('Number of Job Postings', fontsize=12)
plt.tight_layout()
plt.show()
